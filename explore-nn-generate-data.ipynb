# %%
import numpy as np
from skimage.draw import polygon

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# %run nn_generate_data.py

# %%
plt.imshow(random_polygon(64, 64, 5), interpolation='nearest')

# %%
size = 128

fg, bg = load_default_textures(size, size)
fig, ax = plt.subplots(1,2, figsize=(10, 5))
ax[0].imshow(fg);
ax[1].imshow(bg);

# %%
# %time img, mask = random_textured_polygon(fg, bg, size, size, sides=5)
fig, ax = plt.subplots(1,2, figsize=(10, 5))
ax[0].imshow(img)
ax[1].imshow(mask[:,:,0]);
# Out:
# CPU times: user 7.3 ms, sys: 1.48 ms, total: 8.77 ms
# Wall time: 12.3 ms

# %%
# %run nn_generate_data.py
# %time input_data, label_data = generate_grayscale_batch(fg, bg, size, size)
fig, ax = plt.subplots(1,2, figsize=(10, 5))
im0 = ax[0].imshow(input_data[3,:,:,0], cmap=plt.cm.gray)
fig.colorbar(im0, ax=ax[0])
im1 = ax[1].imshow(label_data[3,:,:,0], cmap=plt.cm.gray)
fig.colorbar(im1, ax=ax[1])
# Out:
# CPU times: user 71.1 ms, sys: 1.81 ms, total: 72.9 ms
# Wall time: 72.4 ms

# %%
# %run nn_generate_data.py
# %time input_data, label_data = generate_color_batch(fg, bg, size, size)
fig, ax = plt.subplots(1,3, figsize=(12, 3))
im0 = ax[0].imshow(input_data[3,:,:,0], cmap=plt.cm.gray)
fig.colorbar(im0, ax=ax[0])
im1 = ax[1].imshow(input_data[3,:,:,1], cmap=plt.cm.gray)
fig.colorbar(im1, ax=ax[1])
im2 = ax[2].imshow(input_data[3,:,:,2], cmap=plt.cm.gray)
fig.colorbar(im2, ax=ax[2]);
# Out:
# CPU times: user 80.2 ms, sys: 2.58 ms, total: 82.8 ms
# Wall time: 82.8 ms
