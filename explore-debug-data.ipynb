# %%
import numpy as np
from skimage.draw import polygon

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %run debug-data.py

# %%
plt.imshow(random_polygon(10, 10, 8), interpolation='nearest')

# %%
plt.figure()
plt.imshow(grass_small)
plt.figure()
plt.imshow(stones_small);

# %%
im = random_textured_polygon()
plt.show(im)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-cfec6e83eac7> in <module>()
#       1 im = random_textured_polygon()
# ----> 2 plt.show(im)
#
# /Users/andy/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     242     """
#     243     global _show
# --> 244     return _show(*args, **kw)
#     245
#     246
#
# /Users/andy/anaconda/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      39         # only call close('all') if any to close
#      40         # close triggers gc.collect, which can be slow
# ---> 41         if close and Gcf.get_all_fig_managers():
#      42             matplotlib.pyplot.close('all')
#      43
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
